# %%
import pandas as pd

# %%
df= pd.read_csv("/home/jchan/beeid/notebooks/cmc_experiments/data/untagged_dataset.csv")
df["fake"] = False

# %%
FAKE_IMAGES_PATH="/mnt/storage/work/jchan/untagged_bees/longterm_tail_pretrained/test_latest/images/"
FAKE_SUFFIX=""
# Out:
#         Unnamed: 0  track_id  frame       angle     x    y  parts_num  tag_id  \
# 0                0      5235  11196  193.240520  1444  508          4     NaN
# 1                1      2147   5760  180.000000  1696  672          4     NaN
# 2                2      1928   7780  180.000000   824  960          4     NaN
# 3                3       597   2858  153.434949  1060  860          4     NaN
# 4                4      1225   3934  123.111342   628  964          4     NaN
# ...            ...       ...    ...         ...   ...  ...        ...     ...
# 109649      109649      1626   5922  137.290610   504  672          4     NaN
# 109650      109650      1323   3018  174.957549  1244  600          4     NaN
# 109651      109651      4854  11628  182.121096   672  632          4     NaN
# 109652      109652        56   1614  213.690068  1312  468          4     NaN
# 109653      109653      3594   9722  156.571307   428  992          4     NaN
#
# ...
