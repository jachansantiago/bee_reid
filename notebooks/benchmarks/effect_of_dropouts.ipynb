# %%
import glob
from beeid2.evaluation import load_benchmark
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
no_dropout_benchmark = load_benchmark("../../models4/")

# %%
no_dropout_benchmark
# Out:
#          date                  model_name    agg  tagged  untagged  \
# 0  2203311645  simplecnnv2_convb3_dim_128  image    True      True
# 1  2203301542  simplecnnv2_convb3_dim_128  image   False      True
# 2  2203301512  simplecnnv2_convb3_dim_128  image    True     False
# 3  2203301921  simplecnnv2_convb3_dim_128  image   False      True
# 4  2203300150  simplecnnv2_convb3_dim_128  image   False      True
# 5  2203311707  simplecnnv2_convb3_dim_128  image    True      True
# 6  2203292136  simplecnnv2_convb3_dim_128  image   False      True
# 7  2203300121  simplecnnv2_convb3_dim_128  image    True     False
#
#    augmentation                                      dataset  rank1_same_hour  \
# 0         False  tagged_augmentataion_untagged_augmentataion         0.719763
# 1         False             untagged_augmented_augmentataion         0.511079
# 2         False                                       tagged         0.501368
# ...

# %%
dropout_benchmark = load_benchmark("../../models2/")
dropout_benchmark["benchmark"] = "new"
dropout_benchmark.loc[dropout_benchmark.date == "2110060000", "benchmark"] = "old"
dropout_benchmark = dropout_benchmark[dropout_benchmark.benchmark == "new"]
# Out:
# Something worng with ../../models2/2202041617_untagged_augmented_simplecnnv2_convb3_dim_128/
# Something worng with ../../models2/2202040944_untagged_augmented_augmentataion_simplecnnv2_convb3_dim_128/

# %%
dropout_benchmark
# Out:
#           date                  model_name    agg  tagged  untagged  \
# 1   2202071612  simplecnnv2_convb3_dim_128  image   False      True
# 2   2111240358  simplecnnv2_convb3_dim_128  image    True     False
# 3   2111231639  simplecnnv2_convb3_dim_128  image   False      True
# 5   2111240952  simplecnnv2_convb3_dim_128  image    True      True
# 6   2111232233  simplecnnv2_convb3_dim_128  image    True     False
# 8   2202072211  simplecnnv2_convb3_dim_128  image   False      True
# 11  2111241016  simplecnnv2_convb3_dim_128  image    True      True
# 12  2202032307  simplecnnv2_convb3_dim_128  image   False      True
# 14  2202031053  simplecnnv2_convb3_dim_128  image   False      True
# 15  2111232311  simplecnnv2_convb3_dim_128  image   False      True
#
#     augmentation                                      dataset  \
# 1          False             untagged_augmented_augmentataion
# 2          False                                       tagged
# ...
