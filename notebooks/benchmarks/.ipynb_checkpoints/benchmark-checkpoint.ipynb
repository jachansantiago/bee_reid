# %%
import glob
from beeid2.evaluation import load_benchmark
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
old_benchmark = load_benchmark("../../models/")
old_benchmark = old_benchmark[old_benchmark.model_name == "simplecnnv2_convb3_dim_128"]
old_benchmark["benchmark"] = "old"
# Out:
# Something worng with ../../models/pretraining_triplet_loss.tf/
# Something worng with ../../models/contrastive_loss_T1.tf/
# Something worng with ../../models/pretraining_contrastive_loss_t0-1.tf/
# Something worng with ../../models/pretraining_triplet_loss_no_augematation.tf/
# Something worng with ../../models/pretraining_triplet_loss_362_ids.tf/
# Something worng with ../../models/2111011257_untagged_augmentataion_mobilenetv2_1.00_224/
# Something worng with ../../models/triplet_loss_pretrained_with_triplet_loss.tf/
# Something worng with ../../models/triplet_loss.tf/
# Something worng with ../../models/contrastive_loss_T0-1.tf/
# Something worng with ../../models/triplet_loss_pretrained_no_augmentation.tf/
# Something worng with ../../models/triplet_loss_no_augmentation.tf/
# Something worng with ../../models/pretraining_triplet_loss_181_ids.tf/
# Something worng with ../../models/pretraining_triplet_loss_724_ids.tf/
# Something worng with ../../models/track4_triplet_loss_pretrained_mean.tf/
# Something worng with ../../models/contrastive_loss_T0-1_pretrained.tf/
# Something worng with ../../models/triplet_loss_pretrained.tf/
# Something worng with ../../models/pretraining_triplet_loss_2896_ids.tf/
# Something worng with ../../models/contrastive_loss.tf/
# Something worng with ../../models/pretraining_triplet_loss_1448_ids.tf/

# %%
new_benchmark = load_benchmark("../../models2/")
new_benchmark["benchmark"] = "new"
new_benchmark.loc[new_benchmark.date == "2110060000", "benchmark"] = "old"
# Out:
# Something worng with ../../models2/2202041617_untagged_augmented_simplecnnv2_convb3_dim_128/
# Something worng with ../../models2/2202040944_untagged_augmented_augmentataion_simplecnnv2_convb3_dim_128/

# %%
new_benchmark
# Out:
#           date                  model_name    agg  tagged  untagged  \
# 0   2110060000  simplecnnv2_convb3_dim_128  image    True     False
# 1   2202071612  simplecnnv2_convb3_dim_128  image   False      True
# 2   2111240358  simplecnnv2_convb3_dim_128  image    True     False
# 3   2111231639  simplecnnv2_convb3_dim_128  image   False      True
# 4   2110060000  simplecnnv2_convb3_dim_128  image   False      True
# 5   2111240952  simplecnnv2_convb3_dim_128  image    True      True
# 6   2111232233  simplecnnv2_convb3_dim_128  image    True     False
# 7   2110060000  simplecnnv2_convb3_dim_128  image   False      True
# 8   2202072211  simplecnnv2_convb3_dim_128  image   False      True
# 9   2110060000  simplecnnv2_convb3_dim_128  image    True      True
# 10  2110060000  simplecnnv2_convb3_dim_128  image    True      True
# 11  2111241016  simplecnnv2_convb3_dim_128  image    True      True
# 12  2202032307  simplecnnv2_convb3_dim_128  image   False      True
# 13  2110060000  simplecnnv2_convb3_dim_128  image    True     False
# 14  2202031053  simplecnnv2_convb3_dim_128  image   False      True
# 15  2111232311  simplecnnv2_convb3_dim_128  image   False      True
#
#     augmentation                                      dataset  \
# 0          False                         tagged_augmentataion
# 1          False             untagged_augmented_augmentataion
# 2          False                                       tagged
# 3          False                       untagged_augmentataion
# 4          False                                     untagged
# 5          False  tagged_augmentataion_untagged_augmentataion
# 6          False                         tagged_augmentataion
# 7           True                        untagged_augmentation
# 8          False                           untagged_augmented
# 9          False                              tagged_untagged
# 10         False  tagged_augmentataion_untagged_augmentataion
# 11         False                              tagged_untagged
# 12         False                           untagged_augmented
# 13         False                                       tagged
# 14         False             untagged_augmented_augmentataion
# 15         False                                     untagged
#
#     rank1_same_hour  rank3_same_hour  rank1_diff_day_same_hour  \
# 0          0.541579         0.827763                  0.421308
# 1          0.620632         0.858132                  0.473671
# 2          0.456447         0.732500                  0.322574
# 3          0.738342         0.911947                  0.579451
# 4          0.544395         0.787500                  0.363333
# 5          0.758553         0.912553                  0.651055
# 6          0.529211         0.780737                  0.390506
# 7          0.680474         0.885000                  0.538481
# 8          0.583947         0.843763                  0.413038
# 9          0.582684         0.821895                  0.412447
# 10         0.750947         0.929921                  0.612658
# 11         0.801211         0.932632                  0.658650
# 12         0.286105         0.532053                  0.285401
# 13         0.401579         0.677395                  0.383629
# 14         0.328053         0.558868                  0.272110
# 15         0.682289         0.887579                  0.507848
#
#     rank3_diff_day_same_hour  rank1_diff_day  rank3_diff_day  \
# 0                   0.737173        0.357637        0.668097
# 1                   0.781435        0.424167        0.718789
# 2                   0.610380        0.273463        0.556629
# 3                   0.830675        0.497907        0.787577
# 4                   0.688903        0.318097        0.608677
# 5                   0.879789        0.585793        0.832238
# 6                   0.708819        0.362706        0.664496
# 7                   0.813882        0.479829        0.760691
# 8                   0.722025        0.326853        0.623535
# 9                   0.660970        0.361962        0.635767
# 10                  0.881055        0.570395        0.868078
# 11                  0.888692        0.624180        0.868025
# 12                  0.522405        0.257953        0.485181
# 13                  0.622743        0.282719        0.536471
# 14                  0.542489        0.278367        0.530026
# 15                  0.775443        0.435793        0.720263
#
#                                              filename benchmark
# 0   ../../models2/2110060000_tagged_augmentataion_...       old
# 1   ../../models2/2202071612_untagged_augmented_au...       new
# 2   ../../models2/2111240358_tagged_simplecnnv2_co...       new
# 3   ../../models2/2111231639_untagged_augmentataio...       new
# 4   ../../models2/2110060000_untagged_simplecnnv2_...       old
# 5   ../../models2/2111240952_tagged_augmentataion_...       new
# 6   ../../models2/2111232233_tagged_augmentataion_...       new
# 7   ../../models2/2110060000_untagged_augmentation...       old
# 8   ../../models2/2202072211_untagged_augmented_si...       new
# 9   ../../models2/2110060000_tagged_untagged_simpl...       old
# 10  ../../models2/2110060000_tagged_augmentataion_...       old
# 11  ../../models2/2111241016_tagged_untagged_simpl...       new
# 12  ../../models2/2202032307_untagged_augmented_si...       new
# 13  ../../models2/2110060000_tagged_simplecnnv2_co...       old
# 14  ../../models2/2202031053_untagged_augmented_au...       new
# 15  ../../models2/2111232311_untagged_simplecnnv2_...       new

# %%
results = pd.concat([old_benchmark, new_benchmark])

# %%
results.to_csv("../results.csv")

# %%
new_benchmark.sort_values("date")
# Out:
#           date                  model_name    agg  tagged  untagged  \
# 0   2110060000  simplecnnv2_convb3_dim_128  image    True     False
# 4   2110060000  simplecnnv2_convb3_dim_128  image   False      True
# 7   2110060000  simplecnnv2_convb3_dim_128  image   False      True
# 9   2110060000  simplecnnv2_convb3_dim_128  image    True      True
# 10  2110060000  simplecnnv2_convb3_dim_128  image    True      True
# 13  2110060000  simplecnnv2_convb3_dim_128  image    True     False
# 3   2111231639  simplecnnv2_convb3_dim_128  image   False      True
# 6   2111232233  simplecnnv2_convb3_dim_128  image    True     False
# 15  2111232311  simplecnnv2_convb3_dim_128  image   False      True
# 2   2111240358  simplecnnv2_convb3_dim_128  image    True     False
# 5   2111240952  simplecnnv2_convb3_dim_128  image    True      True
# 11  2111241016  simplecnnv2_convb3_dim_128  image    True      True
# 14  2202031053  simplecnnv2_convb3_dim_128  image   False      True
# 12  2202032307  simplecnnv2_convb3_dim_128  image   False      True
# 1   2202071612  simplecnnv2_convb3_dim_128  image   False      True
# 8   2202072211  simplecnnv2_convb3_dim_128  image   False      True
#
#     augmentation                                      dataset  \
# 0          False                         tagged_augmentataion
# 4          False                                     untagged
# 7           True                        untagged_augmentation
# 9          False                              tagged_untagged
# 10         False  tagged_augmentataion_untagged_augmentataion
# 13         False                                       tagged
# 3          False                       untagged_augmentataion
# 6          False                         tagged_augmentataion
# 15         False                                     untagged
# 2          False                                       tagged
# 5          False  tagged_augmentataion_untagged_augmentataion
# 11         False                              tagged_untagged
# 14         False             untagged_augmented_augmentataion
# 12         False                           untagged_augmented
# 1          False             untagged_augmented_augmentataion
# 8          False                           untagged_augmented
#
#     rank1_same_hour  rank3_same_hour  rank1_diff_day_same_hour  \
# 0          0.541579         0.827763                  0.421308
# 4          0.544395         0.787500                  0.363333
# 7          0.680474         0.885000                  0.538481
# 9          0.582684         0.821895                  0.412447
# 10         0.750947         0.929921                  0.612658
# 13         0.401579         0.677395                  0.383629
# 3          0.738342         0.911947                  0.579451
# 6          0.529211         0.780737                  0.390506
# 15         0.682289         0.887579                  0.507848
# 2          0.456447         0.732500                  0.322574
# 5          0.758553         0.912553                  0.651055
# 11         0.801211         0.932632                  0.658650
# 14         0.328053         0.558868                  0.272110
# 12         0.286105         0.532053                  0.285401
# 1          0.620632         0.858132                  0.473671
# 8          0.583947         0.843763                  0.413038
#
#     rank3_diff_day_same_hour  rank1_diff_day  rank3_diff_day  \
# 0                   0.737173        0.357637        0.668097
# 4                   0.688903        0.318097        0.608677
# 7                   0.813882        0.479829        0.760691
# 9                   0.660970        0.361962        0.635767
# 10                  0.881055        0.570395        0.868078
# 13                  0.622743        0.282719        0.536471
# 3                   0.830675        0.497907        0.787577
# 6                   0.708819        0.362706        0.664496
# 15                  0.775443        0.435793        0.720263
# 2                   0.610380        0.273463        0.556629
# 5                   0.879789        0.585793        0.832238
# 11                  0.888692        0.624180        0.868025
# 14                  0.542489        0.278367        0.530026
# 12                  0.522405        0.257953        0.485181
# 1                   0.781435        0.424167        0.718789
# 8                   0.722025        0.326853        0.623535
#
#                                              filename benchmark
# 0   ../../models2/2110060000_tagged_augmentataion_...       old
# 4   ../../models2/2110060000_untagged_simplecnnv2_...       old
# 7   ../../models2/2110060000_untagged_augmentation...       old
# 9   ../../models2/2110060000_tagged_untagged_simpl...       old
# 10  ../../models2/2110060000_tagged_augmentataion_...       old
# 13  ../../models2/2110060000_tagged_simplecnnv2_co...       old
# 3   ../../models2/2111231639_untagged_augmentataio...       new
# 6   ../../models2/2111232233_tagged_augmentataion_...       new
# 15  ../../models2/2111232311_untagged_simplecnnv2_...       new
# 2   ../../models2/2111240358_tagged_simplecnnv2_co...       new
# 5   ../../models2/2111240952_tagged_augmentataion_...       new
# 11  ../../models2/2111241016_tagged_untagged_simpl...       new
# 14  ../../models2/2202031053_untagged_augmented_au...       new
# 12  ../../models2/2202032307_untagged_augmented_si...       new
# 1   ../../models2/2202071612_untagged_augmented_au...       new
# 8   ../../models2/2202072211_untagged_augmented_si...       new

# %%
# new_benchmark.sort_values("date").to_csv("benchmark.csv")

# %%
# paper_benchmark

# %%
new_benchmark
# Out:
#           date                  model_name    agg  tagged  untagged  \
# 0   2110060000  simplecnnv2_convb3_dim_128  image    True     False
# 1   2202071612  simplecnnv2_convb3_dim_128  image   False      True
# 2   2111240358  simplecnnv2_convb3_dim_128  image    True     False
# 3   2111231639  simplecnnv2_convb3_dim_128  image   False      True
# 4   2110060000  simplecnnv2_convb3_dim_128  image   False      True
# 5   2111240952  simplecnnv2_convb3_dim_128  image    True      True
# 6   2111232233  simplecnnv2_convb3_dim_128  image    True     False
# 7   2110060000  simplecnnv2_convb3_dim_128  image   False      True
# 8   2202072211  simplecnnv2_convb3_dim_128  image   False      True
# 9   2110060000  simplecnnv2_convb3_dim_128  image    True      True
# 10  2110060000  simplecnnv2_convb3_dim_128  image    True      True
# 11  2111241016  simplecnnv2_convb3_dim_128  image    True      True
# 12  2202032307  simplecnnv2_convb3_dim_128  image   False      True
# 13  2110060000  simplecnnv2_convb3_dim_128  image    True     False
# 14  2202031053  simplecnnv2_convb3_dim_128  image   False      True
# 15  2111232311  simplecnnv2_convb3_dim_128  image   False      True
#
#     augmentation                                      dataset  \
# 0          False                         tagged_augmentataion
# 1          False             untagged_augmented_augmentataion
# 2          False                                       tagged
# 3          False                       untagged_augmentataion
# 4          False                                     untagged
# 5          False  tagged_augmentataion_untagged_augmentataion
# 6          False                         tagged_augmentataion
# 7           True                        untagged_augmentation
# 8          False                           untagged_augmented
# 9          False                              tagged_untagged
# 10         False  tagged_augmentataion_untagged_augmentataion
# 11         False                              tagged_untagged
# 12         False                           untagged_augmented
# 13         False                                       tagged
# 14         False             untagged_augmented_augmentataion
# 15         False                                     untagged
#
#     rank1_same_hour  rank3_same_hour  rank1_diff_day_same_hour  \
# 0          0.541579         0.827763                  0.421308
# 1          0.620632         0.858132                  0.473671
# 2          0.456447         0.732500                  0.322574
# 3          0.738342         0.911947                  0.579451
# 4          0.544395         0.787500                  0.363333
# 5          0.758553         0.912553                  0.651055
# 6          0.529211         0.780737                  0.390506
# 7          0.680474         0.885000                  0.538481
# 8          0.583947         0.843763                  0.413038
# 9          0.582684         0.821895                  0.412447
# 10         0.750947         0.929921                  0.612658
# 11         0.801211         0.932632                  0.658650
# 12         0.286105         0.532053                  0.285401
# 13         0.401579         0.677395                  0.383629
# 14         0.328053         0.558868                  0.272110
# 15         0.682289         0.887579                  0.507848
#
#     rank3_diff_day_same_hour  rank1_diff_day  rank3_diff_day  \
# 0                   0.737173        0.357637        0.668097
# 1                   0.781435        0.424167        0.718789
# 2                   0.610380        0.273463        0.556629
# 3                   0.830675        0.497907        0.787577
# 4                   0.688903        0.318097        0.608677
# 5                   0.879789        0.585793        0.832238
# 6                   0.708819        0.362706        0.664496
# 7                   0.813882        0.479829        0.760691
# 8                   0.722025        0.326853        0.623535
# 9                   0.660970        0.361962        0.635767
# 10                  0.881055        0.570395        0.868078
# 11                  0.888692        0.624180        0.868025
# 12                  0.522405        0.257953        0.485181
# 13                  0.622743        0.282719        0.536471
# 14                  0.542489        0.278367        0.530026
# 15                  0.775443        0.435793        0.720263
#
#                                              filename benchmark
# 0   ../../models2/2110060000_tagged_augmentataion_...       old
# 1   ../../models2/2202071612_untagged_augmented_au...       new
# 2   ../../models2/2111240358_tagged_simplecnnv2_co...       new
# 3   ../../models2/2111231639_untagged_augmentataio...       new
# 4   ../../models2/2110060000_untagged_simplecnnv2_...       old
# 5   ../../models2/2111240952_tagged_augmentataion_...       new
# 6   ../../models2/2111232233_tagged_augmentataion_...       new
# 7   ../../models2/2110060000_untagged_augmentation...       old
# 8   ../../models2/2202072211_untagged_augmented_si...       new
# 9   ../../models2/2110060000_tagged_untagged_simpl...       old
# 10  ../../models2/2110060000_tagged_augmentataion_...       old
# 11  ../../models2/2111241016_tagged_untagged_simpl...       new
# 12  ../../models2/2202032307_untagged_augmented_si...       new
# 13  ../../models2/2110060000_tagged_simplecnnv2_co...       old
# 14  ../../models2/2202031053_untagged_augmented_au...       new
# 15  ../../models2/2111232311_untagged_simplecnnv2_...       new

# %%
new_benchmark[new_benchmark.benchmark == "new"]
# Out:
#           date                  model_name    agg  tagged  untagged  \
# 1   2202071612  simplecnnv2_convb3_dim_128  image   False      True
# 2   2111240358  simplecnnv2_convb3_dim_128  image    True     False
# 3   2111231639  simplecnnv2_convb3_dim_128  image   False      True
# 5   2111240952  simplecnnv2_convb3_dim_128  image    True      True
# 6   2111232233  simplecnnv2_convb3_dim_128  image    True     False
# 8   2202072211  simplecnnv2_convb3_dim_128  image   False      True
# 11  2111241016  simplecnnv2_convb3_dim_128  image    True      True
# 12  2202032307  simplecnnv2_convb3_dim_128  image   False      True
# 14  2202031053  simplecnnv2_convb3_dim_128  image   False      True
# 15  2111232311  simplecnnv2_convb3_dim_128  image   False      True
#
#     augmentation                                      dataset  \
# 1          False             untagged_augmented_augmentataion
# 2          False                                       tagged
# 3          False                       untagged_augmentataion
# 5          False  tagged_augmentataion_untagged_augmentataion
# 6          False                         tagged_augmentataion
# 8          False                           untagged_augmented
# 11         False                              tagged_untagged
# 12         False                           untagged_augmented
# 14         False             untagged_augmented_augmentataion
# 15         False                                     untagged
#
#     rank1_same_hour  rank3_same_hour  rank1_diff_day_same_hour  \
# 1          0.620632         0.858132                  0.473671
# 2          0.456447         0.732500                  0.322574
# 3          0.738342         0.911947                  0.579451
# 5          0.758553         0.912553                  0.651055
# 6          0.529211         0.780737                  0.390506
# 8          0.583947         0.843763                  0.413038
# 11         0.801211         0.932632                  0.658650
# 12         0.286105         0.532053                  0.285401
# 14         0.328053         0.558868                  0.272110
# 15         0.682289         0.887579                  0.507848
#
#     rank3_diff_day_same_hour  rank1_diff_day  rank3_diff_day  \
# 1                   0.781435        0.424167        0.718789
# 2                   0.610380        0.273463        0.556629
# 3                   0.830675        0.497907        0.787577
# 5                   0.879789        0.585793        0.832238
# 6                   0.708819        0.362706        0.664496
# 8                   0.722025        0.326853        0.623535
# 11                  0.888692        0.624180        0.868025
# 12                  0.522405        0.257953        0.485181
# 14                  0.542489        0.278367        0.530026
# 15                  0.775443        0.435793        0.720263
#
#                                              filename benchmark
# 1   ../../models2/2202071612_untagged_augmented_au...       new
# 2   ../../models2/2111240358_tagged_simplecnnv2_co...       new
# 3   ../../models2/2111231639_untagged_augmentataio...       new
# 5   ../../models2/2111240952_tagged_augmentataion_...       new
# 6   ../../models2/2111232233_tagged_augmentataion_...       new
# 8   ../../models2/2202072211_untagged_augmented_si...       new
# 11  ../../models2/2111241016_tagged_untagged_simpl...       new
# 12  ../../models2/2202032307_untagged_augmented_si...       new
# 14  ../../models2/2202031053_untagged_augmented_au...       new
# 15  ../../models2/2111232311_untagged_simplecnnv2_...       new

# %%
paper_benchmark = new_benchmark[new_benchmark.benchmark == "new"].drop([1,8,  12, 14])
# paper_benchmark["training protocol"] = ["long-term", "short-term", "short-term + long-term", "long-term", "short-term + long-term", "short-term"]
paper_benchmark["training protocol"] = ["long-term", "short-term", "short-term + long-term", "long-term", "short-term + long-term", "short-term"]
paper_benchmark["augmentation"] = [False, True, True, True, False, False]

no_aug = paper_benchmark[paper_benchmark.augmentation == False]
aug = paper_benchmark[paper_benchmark.augmentation == True]

# %%
pb = no_aug.merge(aug, on="training protocol", suffixes=("", "_aug"))

# %%
pb.columns
# Out:
# Index(['date', 'model_name', 'agg', 'tagged', 'untagged', 'augmentation',
#        'dataset', 'rank1_same_hour', 'rank3_same_hour',
#        'rank1_diff_day_same_hour', 'rank3_diff_day_same_hour',
#        'rank1_diff_day', 'rank3_diff_day', 'filename', 'benchmark',
#        'training protocol', 'date_aug', 'model_name_aug', 'agg_aug',
#        'tagged_aug', 'untagged_aug', 'augmentation_aug', 'dataset_aug',
#        'rank1_same_hour_aug', 'rank3_same_hour_aug',
#        'rank1_diff_day_same_hour_aug', 'rank3_diff_day_same_hour_aug',
#        'rank1_diff_day_aug', 'rank3_diff_day_aug', 'filename_aug',
#        'benchmark_aug'],
#       dtype='object')

# %%
pb
# Out:
#          date                  model_name    agg  tagged  untagged  \
# 0  2111240358  simplecnnv2_convb3_dim_128  image    True     False
# 1  2111241016  simplecnnv2_convb3_dim_128  image    True      True
# 2  2111232311  simplecnnv2_convb3_dim_128  image   False      True
#
#    augmentation          dataset  rank1_same_hour  rank3_same_hour  \
# 0         False           tagged         0.456447         0.732500
# 1         False  tagged_untagged         0.801211         0.932632
# 2         False         untagged         0.682289         0.887579
#
#    rank1_diff_day_same_hour  ...  augmentation_aug  \
# 0                  0.322574  ...              True
# 1                  0.658650  ...              True
# 2                  0.507848  ...              True
#
#                                    dataset_aug  rank1_same_hour_aug  \
# 0                         tagged_augmentataion             0.529211
# 1  tagged_augmentataion_untagged_augmentataion             0.758553
# 2                       untagged_augmentataion             0.738342
#
#   rank3_same_hour_aug rank1_diff_day_same_hour_aug  \
# 0            0.780737                     0.390506
# 1            0.912553                     0.651055
# 2            0.911947                     0.579451
#
#   rank3_diff_day_same_hour_aug rank1_diff_day_aug rank3_diff_day_aug  \
# 0                     0.708819           0.362706           0.664496
# 1                     0.879789           0.585793           0.832238
# 2                     0.830675           0.497907           0.787577
#
#                                         filename_aug  benchmark_aug
# 0  ../../models2/2111232233_tagged_augmentataion_...            new
# 1  ../../models2/2111240952_tagged_augmentataion_...            new
# 2  ../../models2/2111231639_untagged_augmentataio...            new
#
# [3 rows x 31 columns]

# %%
cols = pb.columns.tolist()
cols[7] = "same day; same hour"
cols[9] = "diff day; same hour"
cols[11] = "diff day; any hour"
cols[23] = "same day; same hour w/ aug"
cols[25] = "diff day; same hour w/ aug"
cols[27] = "diff day; any hour w/ aug"
pb.columns = cols

# %%
# Sort Training Protocols
from pandas.api.types import CategoricalDtype
cat_size_order = CategoricalDtype(
    ['long-term', 'short-term', 'short-term + long-term'], 
    ordered=True
)
pb["training protocol"] = pb["training protocol"].astype(cat_size_order)
pb = pb.sort_values("training protocol")

# %%
eval_protocols = ["same day; same hour",
                  "diff day; same hour",
                  "diff day; any hour"]
colors = ["tab:blue", "tab:orange", "tab:red"]
patterns = [ "|" , "\\" , "/" ]
fig, ax = plt.subplots(figsize=(10, 10))
pb.plot(x="training protocol", y=eval_protocols, kind="bar", ylabel="CMC @ Rank 1", ax=ax, color=colors)
plt.xticks(rotation=0);

# bars = ax.patches
# patterns =('-', '+', 'x')
# hatches = [p for p in patterns for i in range(3)]
# for bar, hatch in zip(bars, hatches):
#     bar.set_hatch(hatch)

# %%
np.arange(0, 1.05, 0.05)
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ])

# %%
eval_protocols = ["same day; same hour","same day; same hour w/ aug",
                  "diff day; same hour", "diff day; same hour w/ aug",
                  "diff day; any hour", "diff day; any hour w/ aug"]

colors = ["tab:blue", "dodgerblue", "tab:red", "red", "tab:green", "lime"]
patterns = [ None , "//" , None , "\\" , None , "\\" ]
fig, ax = plt.subplots(figsize=(12, 8))
pb.plot(x="training protocol", y=eval_protocols, kind="bar", ax=ax, color=colors)
plt.xticks(rotation=0, fontsize=22);
plt.yticks(np.arange(0, 1.05, 0.05), fontsize=16);
plt.ylabel("Accuracy", fontsize=22);
plt.grid()
plt.legend(fontsize=12)

bars = ax.patches
# patterns =('-', '+', 'x')
hatches = [p for p in patterns for i in range(3)]
for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)

# %%
pb
# Out:
#          date                  model_name    agg  tagged  untagged  \
# 0  2111240358  simplecnnv2_convb3_dim_128  image    True     False
# 2  2111232311  simplecnnv2_convb3_dim_128  image   False      True
# 1  2111241016  simplecnnv2_convb3_dim_128  image    True      True
#
#    augmentation          dataset  same day; same hour  rank3_same_hour  \
# 0         False           tagged             0.456447         0.732500
# 2         False         untagged             0.682289         0.887579
# 1         False  tagged_untagged             0.801211         0.932632
#
#    diff day; same hour  ...  augmentation_aug  \
# 0             0.322574  ...              True
# 2             0.507848  ...              True
# 1             0.658650  ...              True
#
#                                    dataset_aug  same day; same hour w/ aug  \
# 0                         tagged_augmentataion                    0.529211
# 2                       untagged_augmentataion                    0.738342
# 1  tagged_augmentataion_untagged_augmentataion                    0.758553
#
#   rank3_same_hour_aug diff day; same hour w/ aug rank3_diff_day_same_hour_aug  \
# 0            0.780737                   0.390506                     0.708819
# 2            0.911947                   0.579451                     0.830675
# 1            0.912553                   0.651055                     0.879789
#
#   diff day; any hour w/ aug rank3_diff_day_aug  \
# 0                  0.362706           0.664496
# 2                  0.497907           0.787577
# 1                  0.585793           0.832238
#
#                                         filename_aug  benchmark_aug
# 0  ../../models2/2111232233_tagged_augmentataion_...            new
# 2  ../../models2/2111231639_untagged_augmentataio...            new
# 1  ../../models2/2111240952_tagged_augmentataion_...            new
#
# [3 rows x 31 columns]

# %%
eval_protocols = ["same day; same hour",
                  "diff day; same hour",
                  "diff day; any hour"]

colors = ["tab:blue", "red", "tab:green", "dodgerblue", "red", "lime"]
patterns = [ None , "\\" , None , "\\" , None , "\\" ]
fig, ax = plt.subplots(figsize=(15, 8))
pb.plot(x="training protocol", y=eval_protocols, kind="bar", ax=ax, color=colors).legend(loc='upper left', fontsize=14)
plt.xticks(rotation=0, fontsize=18);
plt.ylabel("CMC @ Rank 1", fontsize=24);
plt.xlabel("Training Protocol", fontsize=24);
plt.grid(True, alpha=0.2)
plt.ylim(0.0, 1.0);
plt.yticks(np.arange(0, 1.05, 0.05), rotation=0, fontsize=12);
# plt.savefig("benchmark1_visapp.png")

# %%
eval_protocols = [
#     "same day; same hour",
#                   "diff day; same hour",
#                   "diff day; any hour", 
                  "same day; same hour w/ aug",
                  "diff day; same hour w/ aug",
                  "diff day; any hour w/ aug"]

colors = ["tab:blue", "red", "tab:green", "dodgerblue", "brown", "lime"]
# patterns = [ "x", "x" , "x", "\\" , "\\" , "\\" ]
fig, ax = plt.subplots(figsize=(15, 8))
pb.plot(x="training protocol", y=eval_protocols, kind="bar", ax=ax, color=colors, ).legend(loc='upper left', fontsize=14)
plt.xticks(rotation=0, fontsize=18);
plt.ylabel("CMC @ Rank 1", fontsize=24);
plt.xlabel("Training Protocol", fontsize=24);
plt.grid(True, alpha=0.2)
plt.ylim(0.0, 1.0);
plt.yticks(np.arange(0, 1.05, 0.05), rotation=0, fontsize=12);

# bars = ax.patches
# # patterns =('-', '+', 'x')
# hatches = [p for p in patterns for i in range(3)]
# for bar, hatch in zip(bars, hatches):
#     bar.set_hatch(hatch)

# plt.savefig("benchmark2_visapp.png")

# %%
nbenchmark = load_benchmark("../../models3/")
nbenchmark["n"] = nbenchmark["date"].str[-4:].astype(int)

# %%
nbenchmark.sort_values("n")
# Out:
#          date                  model_name    agg  tagged  untagged  \
# 5  2110060181  simplecnnv2_convb3_dim_128  image   False      True
# 2  2110060362  simplecnnv2_convb3_dim_128  image   False      True
# 0  2110060724  simplecnnv2_convb3_dim_128  image   False      True
# 4  2110061448  simplecnnv2_convb3_dim_128  image   False      True
# 3  2110062896  simplecnnv2_convb3_dim_128  image   False      True
# 1  2110064949  simplecnnv2_convb3_dim_128  image   False      True
#
#    augmentation                dataset  rank1_same_hour  rank3_same_hour  \
# 5          True  untagged_augmentation         0.182711         0.397263
# 2          True  untagged_augmentation         0.314579         0.577684
# 0          True  untagged_augmentation         0.392000         0.675763
# 4          True  untagged_augmentation         0.547947         0.795289
# 3          True  untagged_augmentation         0.663237         0.884368
# 1          True  untagged_augmentation         0.680474         0.885000
#
#    rank1_diff_day_same_hour  rank3_diff_day_same_hour  rank1_diff_day  \
# 5                  0.111561                  0.322447        0.105853
# 2                  0.239367                  0.463038        0.186333
# 0                  0.249114                  0.534051        0.251093
# 4                  0.422110                  0.687595        0.377867
# 3                  0.504262                  0.773586        0.421211
# 1                  0.538481                  0.813882        0.479829
#
#    rank3_diff_day                                           filename     n
# 5        0.304990  ../../models3/2110060181_untagged_augmentation...   181
# 2        0.407525  ../../models3/2110060362_untagged_augmentation...   362
# 0        0.520434  ../../models3/2110060724_untagged_augmentation...   724
# 4        0.655398  ../../models3/2110061448_untagged_augmentation...  1448
# 3        0.724621  ../../models3/2110062896_untagged_augmentation...  2896
# 1        0.760691  ../../models3/2110064949_untagged_augmentation...  4949

# %%
lt_dict = {
    "n": [181, 181, 181],
    "eval": ["rank1_same_hour", "rank1_diff_day_same_hour", "rank1_diff_day"],
    "train": ["long-term", "long-term", "long-term"],
    "value": [0.529, 0.391, 0.362]
}
ltdf = pd.DataFrame(lt_dict)

# %%
ddff = pd.melt(nbenchmark, value_vars=['rank1_same_hour', 'rank1_diff_day_same_hour', 'rank1_diff_day'], id_vars="n")
ddff["train"] = "short-term"
c = list(ddff.columns.copy())
c[1] = "eval"
ddff.columns = c
ddff = ddff.append(ltdf)

# %%
num_tracks = [181, 362, 724, 1448, 2896, 4949]

plt.figure(figsize=(13, 8))

p = sns.lineplot(x="n", y="value", style="train", hue="eval", markers=True, dashes=False, markersize=16,
         linewidth=5, palette=['b', 'r', 'g'], data=ddff)



# plt.plot(x, x/11, ':', linewidth=2, color="gray")
plt.grid(True)
plt.ylim(0.0, 1.0)
plt.yticks(np.arange(0, 1.05, 0.05), fontsize=22);

plt.xlabel("# tracks", fontsize=28)
plt.ylabel("Accuracy", fontsize=28)
plt.xscale('log')
plt.xticks(num_tracks, ["1X", "2X", "4X", "8X", "16X", "27.3X"], fontsize=22);
plt.tick_params(axis='y', which='minor', bottom=False)
plt.title("Accuracy versus number of tracks.", fontsize=32);
plt.legend(fontsize=18, ncol=2)
plt.tight_layout()
plt.savefig("performanceversusntracks2.png", bbox_inches="tight")
