# %% [markdown]
# # Triplet Loss

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np
import pandas as pd
from tqdm import tqdm
import tensorflow as tf

import matplotlib.pyplot as plt
from ipywidgets import interact

import tensorflow_addons as tfa
from tensorflow.keras.models import load_model
from tensorflow_addons.losses import TripletSemiHardLoss, TripletHardLoss

from beeid.utils import sensitivity_map

from code.models import simple_cnnv2
from code.data_utils import load_tf_dataset
from code.viz import show_sensitivity_maps
from code.evaluation import cmc_evaluation, plot_cmc
from code.evaluation import get_interactive_plot_query_gallery

IMAGE_FOLDER = "/mnt/storage/work/jchan/normalized_uncensored_dataset/images/"
DATASET_CSV = "/mnt/storage/work/jchan/body_dataset2/dataset3.csv"

# %% [markdown]
# ### Prepare dataset
#
# Select the dates for Training, Validation and Testing datasets.

# %%
# def filter_dataframe(df):
#     filtered_df = df[(df.closest_bee > 300)]
#     filtered_df = filtered_df[filtered_df.abdomen_size >= 230]
#     filtered_df = filtered_df[filtered_df.abdomen_angle >= 200]
#     filtered_df = filtered_df[filtered_df.abdomen_angle <= 330]
#     filtered_df = filtered_df[filtered_df.V_mean >= 0.30]
#     return filtered_df.copy()

# df = pd.read_csv(DATASET_CSV)

# df = filter_dataframe(df)
# df= df[df.tag_id != -1.0]
# df["datetime2"] = pd.to_datetime(df["datetime"])
# df["days"] = df["datetime2"].dt.strftime("%Y-%m-%d")
# df["global_track_id"] = df["video_name"] + "_" + df["track_id"].apply(str)
# df["filename"] = IMAGE_FOLDER + df.filename

# train_df = df[df.days <= '2019-07-23']
# valid_df = df[(df.days > '2019-07-23') & (df.days < '2019-07-25')]
# test_df = df[(df.days >= '2019-08-01') & (df.days <= '2019-08-04')]
train_df=pd.read_csv("data/train.csv")
test_df=pd.read_csv("data/test.csv")
valid_df=pd.read_csv("data/valid.csv")

len(train_df), len(valid_df), len(test_df)
# Out:
# (3777, 1909, 3276)

# %% [markdown]
# ### Tensorflow Dataset

# %%
train_dataset = load_tf_dataset(train_df, rescale_factor=4, augmentation=True).shuffle(len(train_df))
valid_dataset = load_tf_dataset(valid_df, rescale_factor=4)

# %%
data = train_dataset.batch(32)
gen = iter(data)
sample_batch = next(gen)

EXAMPLES=2

fig, ax = plt.subplots(4, 8, figsize=(25, 8))
ax = ax.ravel()
for j in range(32):
    ax[j].imshow(sample_batch[0][j])
    ax[j].set_title("{}".format(sample_batch[1][j].numpy()))
    ax[j].set_xticks([])
    ax[j].set_yticks([])

# %% [markdown]
# ### Model

# %%
model = simple_cnnv2(input_shape=(56, 56, 3), conv_blocks=3, latent_dim=128)

# %%
model.load_weights("weights/pretraining_triplet_loss.tf")

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
    loss=TripletSemiHardLoss(margin=0.2))

# %%
# Train the network
BATCH_SIZE=256
EPOCHS=1000
PATIENCE=100


earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

history = model.fit(train_dataset.batch(BATCH_SIZE), validation_data=valid_dataset.batch(BATCH_SIZE), epochs=EPOCHS, callbacks=[earlystop])
# Out:
# Epoch 1/1000
# 15/15 [==============================] - 6s 384ms/step - loss: 0.1405 - val_loss: 0.1072
# Epoch 2/1000
# 15/15 [==============================] - 4s 262ms/step - loss: 0.1240 - val_loss: 0.1078
# Epoch 3/1000
# 15/15 [==============================] - 2s 165ms/step - loss: 0.1097 - val_loss: 0.1077
# Epoch 4/1000
# 15/15 [==============================] - 3s 176ms/step - loss: 0.1039 - val_loss: 0.0989
# Epoch 5/1000
# 15/15 [==============================] - 3s 176ms/step - loss: 0.0989 - val_loss: 0.0980
# Epoch 6/1000
# 15/15 [==============================] - 3s 174ms/step - loss: 0.0959 - val_loss: 0.0966
# Epoch 7/1000
# 15/15 [==============================] - 3s 224ms/step - loss: 0.0896 - val_loss: 0.0948
# Epoch 8/1000
# 15/15 [==============================] - 3s 214ms/step - loss: 0.0895 - val_loss: 0.0973
# Epoch 9/1000

# %%
model.save("models/triplet_loss_pretrained.tf")

# %% [markdown]
# ### Checking Training

# %%
pd.DataFrame(history.history).plot()
# Out:
# <AxesSubplot:>

# %%
show_sensitivity_maps(model, valid_dataset)

# %% [markdown]
# #### Save model

# %%
# model.save("models/triplet_loss.tf")

# %% [markdown]
# ## Evaluation

# %%
ITERATIONS=100
GALLERY_SIZE=10

# %% [markdown]
# ### Evaluation only ids shared with the training set (validation set)

# %%
train_ids = train_df.track_tag_id.unique()

valid_with_shared_ids = valid_df[valid_df.track_tag_id.isin(train_ids)]

valid_with_shared_ids_ranks_means = cmc_evaluation(model, valid_with_shared_ids, iterations=ITERATIONS, gallery_size=GALLERY_SIZE)

plot_cmc(valid_with_shared_ids_ranks_means )
# Out:
#  23%|██▎       | 23/100 [00:29<01:40,  1.30s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-7b0f667e663a> in <module>
#       3 valid_with_shared_ids = valid_df[valid_df.track_tag_id.isin(train_ids)]
#       4
# ----> 5 valid_with_shared_ids_ranks_means = cmc_evaluation(model, valid_with_shared_ids, iterations=ITERATIONS, gallery_size=GALLERY_SIZE)
#       6
#       7 plot_cmc(valid_with_shared_ids_ranks_means )
#
# ~/beeid/notebooks/cmc_experiments/code/evaluation.py in cmc_evaluation(model, df, iterations, gallery_size)
#      99         queries_and_galleries = list()
#     100         for i, query_data in queries.iterrows():
# --> 101             query_gallery =  get_query_gallery(query_data, query_df, dfGroupedbyTagId, limit=gallery_size)
#     102             queries_and_galleries.append(query_gallery)
#     103
#
# ~/beeid/notebooks/cmc_experiments/code/evaluation.py in get_query_gallery(query, query_df, dfGroupedbyTagId, limit)
#      18
#      19 #     negatives = dfGroupedbyTagId.sample()
# ---> 20     negatives = dfGroupedbyTagId.apply(lambda x: x.iloc[np.random.randint(len(x))])
#      21     different_tag = (negatives.index != query.track_tag_id)
#      22     negatives = negatives[different_tag]
#
# ~/anaconda3/envs/bees/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     857         with option_context("mode.chained_assignment", None):
#     858             try:
# --> 859                 result = self._python_apply_general(f, self._selected_obj)
#     860             except TypeError:
#     861                 # gh-20949
#
# ~/anaconda3/envs/bees/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#     893
#     894         return self._wrap_applied_output(
# --> 895             keys, values, not_indexed_same=mutated or self.mutated
#     896         )
#     897
#
# ~/anaconda3/envs/bees/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _wrap_applied_output(self, keys, values, not_indexed_same)
#    1372                     result = _recast_datetimelike_result(result)
#    1373                 else:
# -> 1374                     result = result._convert(datetime=True)
#    1375
#    1376                 if not self.as_index:
#
# ~/anaconda3/envs/bees/lib/python3.7/site-packages/pandas/core/generic.py in _convert(self, datetime, numeric, timedelta, coerce)
#    5714                 timedelta=timedelta,
#    5715                 coerce=coerce,
# -> 5716                 copy=True,
#    5717             )
#    5718         ).__finalize__(self)
#
# ~/anaconda3/envs/bees/lib/python3.7/site-packages/pandas/core/internals/managers.py in convert(self, copy, datetime, numeric, timedelta, coerce)
#     609             numeric=numeric,
#     610             timedelta=timedelta,
# --> 611             coerce=coerce,
#     612         )
#     613
#
# ~/anaconda3/envs/bees/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# ~/anaconda3/envs/bees/lib/python3.7/site-packages/pandas/core/internals/blocks.py in convert(self, copy, datetime, numeric, timedelta, coerce)
#    2418
#    2419         if self.ndim == 2:
# -> 2420             blocks = self.split_and_operate(None, f, False)
#    2421         else:
#    2422             values = f(None, self.values.ravel(), None)
#
# ~/anaconda3/envs/bees/lib/python3.7/site-packages/pandas/core/internals/blocks.py in split_and_operate(self, mask, f, inplace)
#     456             # need a new block
#     457             if m.any():
# --> 458                 nv = f(m, v, i)
#     459             else:
#     460                 nv = v if inplace else v.copy()
#
# ~/anaconda3/envs/bees/lib/python3.7/site-packages/pandas/core/internals/blocks.py in f(mask, val, idx)
#    2409                 timedelta=timedelta,
#    2410                 coerce=coerce,
# -> 2411                 copy=copy,
#    2412             )
#    2413             if isinstance(values, np.ndarray):
#
# ~/anaconda3/envs/bees/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in soft_convert_objects(values, datetime, numeric, timedelta, coerce, copy)
#    1097         # bound of nanosecond-resolution 64-bit integers.
#    1098         try:
# -> 1099             values = lib.maybe_convert_objects(values, convert_datetime=True)
#    1100         except OutOfBoundsDatetime:
#    1101             pass
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_objects()
#
# ~/anaconda3/envs/bees/lib/python3.7/site-packages/numpy/core/numeric.py in full(shape, fill_value, dtype, order)
#     266
#     267
# --> 268 @set_module('numpy')
#     269 def full(shape, fill_value, dtype=None, order='C'):
#     270     """
#
# KeyboardInterrupt:

# %% [markdown]
# ### Evaluation on the whole validation set

# %%
valid_ranks_means = cmc_evaluation(model, valid_df, iterations=ITERATIONS, gallery_size=GALLERY_SIZE)

plot_cmc(valid_ranks_means)

# %% [markdown]
# ### Evaluation on whole test set

# %%
test_ranks_means = cmc_evaluation(model, test_df, iterations=ITERATIONS, gallery_size=GALLERY_SIZE)

plot_cmc(test_ranks_means)

# %%
train_ids = train_df.track_tag_id.unique()
test_ids = test_df.track_tag_id.unique()


intersection = set(train_ids) & set(test_ids)

print("Test set has {} Ids.".format(len(test_ids)))
print("Intersection of train and test set {}".format(len(intersection)))

# %%
test_disjoint_train = test_df[~test_df.track_tag_id.isin(train_ids)]

test_disjoint_train_ranks_means = cmc_evaluation(model, test_disjoint_train, iterations=ITERATIONS, gallery_size=GALLERY_SIZE)

plot_cmc(test_disjoint_train_ranks_means)

# %% [markdown]
# #### Saving results

# %%
metric_dict = dict()

metric_dict["valid_cmc_only_train_ids"] = valid_with_shared_ids_ranks_means 
metric_dict["valid_cmc"] = valid_ranks_means
metric_dict["test_cmc"] = test_ranks_means
metric_dict["test_cmc_no_ids_overlap"] = test_disjoint_train_ranks_means

metric_df = pd.DataFrame(metric_dict)
metric_df.to_csv("results/triplet_loss_pretrained.csv")

# %% [markdown]
# #### Interactive Query Plotting

# %%
get_interactive_plot_query_gallery(model, valid_df)
# Out:
# interactive(children=(IntSlider(value=17, description='query_id', max=34), Checkbox(value=False, description='…
